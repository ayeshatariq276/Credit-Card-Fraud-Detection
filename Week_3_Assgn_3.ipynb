# %% [markdown]
# # Week 3 Assignment: Data Visualization & Exploratory Data Analysis
# **Subject:** Data Science & AI
# **Project:** Credit Card Fraud Detection
# **Student Name:** Ayesha Tariq
# **Date:** September 28, 2025
#
# ---
#
# ##  Objectives
# - Create 5 different plots using the cleaned dataset.
# - Write a short description of insights under each plot.
# - Complete your first Exploratory Data Analysis (EDA) milestone.

# %% [markdown]
# ## 1. Class Distribution (Bar Chart)

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Settings for visuals
sns.set(style="whitegrid", palette="muted")

# Load the cleaned dataset (make sure the file is uploaded in Colab)
df = pd.read_csv("creditcard_sample.csv")


print(" Dataset loaded successfully!")
print("Shape:", df.shape)
df.head()
# Out:
#  Dataset loaded successfully!
# Shape: (9, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791460
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010308  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921 -0.677020
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846 -0.342715
# 2  0.247676 -1.514654  ...  0.237698  0.377436 -0.387924 -0.054951 -0.594927
# 3  0.377436 -1.387024  ... -0.594911 -0.077659 -0.202020  0.272673  0.198400
# ...

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="Class", data=df, palette=["#4CAF50", "#E74C3C"])
plt.title("Distribution of Fraudulent vs Non-Fraudulent Transactions")
plt.xlabel("Class (0 = Normal, 1 = Fraud)")
plt.ylabel("Count")
plt.show()
# Out:
# /tmp/ipython-input-832474612.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Class", data=df, palette=["#4CAF50", "#E74C3C"])

# %% [markdown]
# ## 2. Transaction Amount by Class (Boxplot)

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x="Class", y="Amount", data=df, palette="Set2")
plt.title("Transaction Amounts by Class")
plt.xlabel("Class (0 = Normal, 1 = Fraud)")
plt.ylabel("Amount ($)")
plt.show()
# Out:
# /tmp/ipython-input-2965085602.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Class", y="Amount", data=df, palette="Set2")

# %% [markdown]
# ## 3. Distribution of Transaction Amounts (Histogram)

# %%
plt.figure(figsize=(8,4))
sns.histplot(df["Amount"], bins=50, kde=True, color="skyblue")
plt.title("Distribution of Transaction Amounts")
plt.xlabel("Amount ($)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## 4. Correlation Heatmap

# %%
plt.figure(figsize=(10,8))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap of Features")
plt.show()

# %% [markdown]
# ## 5. Scatter Plot Relationship Between Two PCA Features

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(
    x="V2", y="V4", hue="Class", data=df,
    palette={0: "gray", 1: "red"}, alpha=0.6
)
plt.title("Scatter Plot: V2 vs V4 (Colored by Class)")
plt.xlabel("V2")
plt.ylabel("V4")
plt.legend(title="Class")
plt.show()

# %% [markdown]
# ## Week 3 Summary Exploratory Data Analysis Milestone
#
# | Visualization | Type | Insight |
# |----------------|------|----------|
# | 1 | Bar Chart | Shows strong class imbalance |
# | 2 | Boxplot | Fraud amounts are generally smaller |
# | 3 | Histogram | Most transactions are low-value |
# | 4 | Heatmap | Weak feature correlations (PCA data) |
# | 5 | Scatter Plot | Visible separation for fraud cases |
